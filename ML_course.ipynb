# %% [markdown]
# <a href="https://colab.research.google.com/github/Jubaida-78/Machine-Learning-with-python/blob/main/ML_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix#for heatmap
import seaborn as sns
import sklearn as svm
from sklearn import svm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from PIL import ImageOps
from PIL import Image
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.math import confusion_matrix
import cv2
from google.colab.patches import cv2_imshow
import os
import json
import zipfile
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity
import re
import nltk
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %%
# !pip install pandas

# %%
# !ls

# %% [markdown]
# Data type in python:
# 1.Integer
# 2.Foating point
# 3.Complex
# 4.Boolean
# 5.String

# %%
a=5
print(type(a))
b=1.5
print(type(b))
c=1+5j
print(type(c))
d=True
print(type(d))
e='Jubaida'
print(type(e))
ee='106'
print(type(ee))

#converting int to float
f=106
print(type(f))
g=float(f)
print(type(g))

# %%
print('jubaida '*5)
j='jubaida'
print(j[0:4])
print(j[0:7:2])

# %% [markdown]
# Type of object in  python:
# 1.Immutable (int,float,string,bool,tuple)
# 2.mutable(list,set,dictionary)

# %%
#LIST
lis=[1,2,3,4,5]
print(lis)
type(lis)
myList=[6,7,8,9,'jubaida',True,8]
myList.append(106)
print(myList)
print(myList[4])
print(len(myList))

myList2=[1,2,3,4]
del myList2[2]
print(myList2)
myList4=myList+myList2
print(myList4)

# %%
#TUPLE
tuple1=(1,2,3,4,5)
print(tuple1)
type(tuple1)
tuple2=(6,7,8,9,'jubaida',False,1.5)
print(tuple2)
myList=[6,7,8,9,'jubaida',True,8]
tuple3=tuple(myList)
print(tuple3)
print(tuple3[4])
print(len(tuple3))

# %%
#SET //set does not allow duplicate but list and tuple do
mySet={1,2,3,4,5}
print(mySet)
type(mySet)
mySet2={6,7,8,9,'jubaida',False,1.5}
print(mySet2)

# %%
#DICTIONARY//notallow duplicate value
#key value pair
myDic={'name':'Jubaida','age':'24'}
print(myDic)
type(myDic)

# %%
print(myDic['name'])

# %%
#identity operator
a=5
b=6
print(a is b)

print(a is not b)

# %%
#MEMBERSHIP OPERATOR
a=5
b=7
c=[1,2,4,5,6,8]
print(a in c)
print(b in c)
print(a in c)
print(b in c)

# %% [markdown]
# #NUMPY

# %%
import numpy as np
from time  import process_time

# %%
#TIME TAKEN BY A LIST
list2=[i for i in range(10000)]
start_time=process_time()
list2=[i+5 for i in list2]
end_time=process_time()
print(end_time-start_time)

# %%
np_array=np.array([i for i in range(10000)])
start_time=process_time()
np_array +=5
end_time=process_time()
print(end_time-start_time)

# %%
#NUMPY ARRAY
list3=[1,2,3,4]
print(list3)
type(list3)
np_array=np.array([1,2,3,4])
print(np_array)
type(np_array)

# %%
a=np.array([(1,2,3,4),(5,6,7,8)],dtype=float)
print(a)
a.shape

# %%
#CRAETE A NUMPY ARRAY
X=np.zeros((4,5))
print(X)
y=np.ones((4,6))
print(y)
z=np.full((5,4),6)
print(z)

# %%
#IDENTITY MATRIX
z=np.eye(4)
print(z)

# %%
z=np.random.random((3,4))
print(z)
print('#############################')
zz=np.random.randint(10,100,(3,5))
print(zz)

# %%
#ARRAY EVENLY SPACED
z=np.linspace(10,20,5)
print(z)
zz=np.arange(10,30,5)
print(zz)

# %%
a=np.random.randint(0,10,(3,4))
b=np.random.randint(10,20,(3,4))
print(a+b)
print(a-b)
print(np.multiply(a,b))

# %%
#TRANSPOSE OF THE MATRIX
trans=np.transpose(a)
print(trans)

# %% [markdown]
# #PANDAS

# %%
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing
HousingData = fetch_california_housing()
df = pd.DataFrame(HousingData.data, columns=HousingData.feature_names)
print(type(df))

# %%
df=pd.read_csv('/content/HousingData.csv')
df.head()

# %%
df.shape
df.count()
df.mean()
df.std()#deviation
df.min()
df.max()
df.describe()

# %% [markdown]
# #MANIPULATING DATAFRAME

# %%
#ADDING A COLUMN TO A DATAFRAME
df['Price']=HousingData.target
df.head()

# %%
sns.displot(df['Price'])

# %%
df.drop(columns='ZN',axis=1)

# %%
#REMOVING ROW
df.drop(index=1,axis=1)

# %%
#REMOVING COLUMN
df.drop(columns='ZN',axis=1)

# %%
#LOCATING A ROW USING INDEX VALUE
df.iloc[2]

# %%
#LOCATING A PARTICULAR COLUMN
print(df.iloc[:,0])
print(df.iloc[:,2])
print(df.iloc[:,-1])

# %%
#CORREALTION
df.corr()
correlation=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':8},cmap='Blues')

# %% [markdown]
# #EXPORTING A DATAFRAME FROM EXCEL TO A CSV FILE

# %%
# !pip install odfpy
aboutExcel = pd.read_excel('/content/ALL METHOD ABOUT EXCEL.ods', engine='odf')
type(aboutExcel)
aboutExcel.to_csv('/content/ALL METHOD ABOUT EXCEL.csv', index=False)

# %%
aboutExcel_df=pd.read_csv('/content/ALL METHOD ABOUT EXCEL.csv')
aboutExcel_df.head()

# %%
df.info()#housing data

# %%
df.isnull().sum()

# %% [markdown]
# #MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
z=np.cos(x)
print(x)
print(y)
print(z)

# %%
#SIN WAVE
plt.plot(x,y)
plt.show

# %%
#COS WAVE
plt.plot(x,z)
plt.show

# %%
#ADDING TITLE
plt.plot(x,y)
plt.xlabel('angel')
plt.ylabel('sine value')
plt.title('sine wave')
plt.show

# %%
#PLOT PARABOLA
x=np.linspace(-10,10,20)
y=x**2
plt.plot(x,y,'r+')
plt.show

# %%
x=np.linspace(-5,5,50)
plt.plot(x,np.sin(x),'g.')
plt.plot(x,np.cos(x),'r--')
plt.show

# %%
#BAR PLOT
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
language=['English','Bangla','Latin','French']
people=[100,50,120,33]
ax.bar(language,people)
plt.xlabel('language')
plt.ylabel('number of people')
plt.title('language usage')
plt.show

# %%
#PIE PLOT
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
language=['English','Bangla','Latin','French']
people=[100,50,120,33]
ax.pie(people, labels=language, autopct='%1.1f%%')
plt.show

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
z=np.cos(x)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x,y,color='g')
ax.scatter(x,z,color='b')
plt.show

# %%
#3D SCATTER
fig2=plt.figure()
ax=plt.axes(projection='3d')
z=20*np.random.random(100)
#z=np.linspace(0,15,1000)
x=np.sin(z)
y=np.cos(z)
ax.scatter(x,y,z,c=z,cmap='Blues')
plt.show

# %% [markdown]
# #SEABORN

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tips=sns.load_dataset('tips')
tips.head()

# %%
sns.set_theme()#bg color
sns.relplot(data=tips,x='total_bill',y='tip',col='time',hue='smoker',style='smoker',size='size')

# %%
iris=sns.load_dataset('iris')
iris.head()

# %%
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=iris)

# %%
sns.scatterplot(x='sepal_length',y='petal_width',hue='species',data=iris)

# %%
titanic=sns.load_dataset('titanic')
titanic.head()

# %%
sns.countplot(x='class',data=titanic)
sns.barplot(x='sex',y='survived',hue='class',data=titanic)

# %% [markdown]
# #DATA FOR MACHINE LEARNING

# %% [markdown]
# #API

# %%
# !pip install kaggle

# %%
# !rm -f ~/.kaggle
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list

# %%
# !kaggle competitions download -c LANL-Earthquake-Prediction

# %% [markdown]
# #SONAR DATASET TO PREDICT

# %%
sonarData=pd.read_csv('/content/sonar.csv',header=None)
sonarData.head()

# %%
sonarData.describe()

# %%
sonarData[60].value_counts()#mM=MINE,R=ROCK

# %%
sonarData.groupby(60).mean()#.max,min,std

# %%
#SEPARATING DATA AND LABEL
x=sonarData.drop(columns=60,axis=1)
y=sonarData[60]

# %%
#TRAINING AND TEST DATA
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,stratify=y,random_state=2)
print(x.shape,x_train.shape,x_test.shape)

# %%
print(x_train)
print(y_train)

# %%
#MODEL TRAINING
model=LogisticRegression()
model.fit(x_train,y_train)

# %%
#MODEL EVALUATION
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)
print('Accuracy on training data:',training_data_accuracy)

# %%
x_test_prediction=model.predict(x_test)
test_data_accuaracy=accuracy_score(x_test_prediction,y_test)
print('Accuracy on test data:',test_data_accuaracy)

# %%
#MAKING A PREDICTIVE SYSTEM
input_data = sonarData.iloc[0, :-1].values

input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)

print(prediction)

if prediction[0] == 'R':
    print('ROCK')
else:
    print('MINE')

# %%
train_test_split_accuracy=accuracy_score(x_train_prediction,y_train)
print(train_test_split_accuracy)

# %% [markdown]
# #SUPPORT VECTOR MACHINE

# %% [markdown]
# #DIABETES DATASET

# %%
diabetesData=pd.read_csv('/content/diabetes.csv')
diabetesData.head()

# %%
diabetesData['Outcome'].value_counts()#0->non-diabetes,1->diabetes

# %%
print(x)
print(y)

# %%
#DTA STANDARDIZATION
scaler=StandardScaler()
scaler.fit(x)
Standardized_data=scaler.transform(x)
print(Standardized_data)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
print(x.shape,x_train.shape,x_test.shape)

# %%
#TRAINING MODEL
classifier=svm.SVC(kernel='linear')
classifier.fit(x_train,y_train)

# %% [markdown]
# #VECTOR OPERATION IN PYTHON

# %%
sns.set()

# %%
plt.quiver(0,0,4,5)
plt.show

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show

# %%
plt.quiver(0,0,-4,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,8,8,scale_units='xy',angles='xy',scale=1,color='g')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show

# %%
vector_1=np.asarray([0,0,4,5])
vector_2=np.asarray([0,0,3,-2])
sum=vector_1+vector_2
print(sum)

# %%
plt.quiver(0,0,-4,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,8,8,scale_units='xy',angles='xy',scale=1,color='g')
plt.quiver(0,0,7,3,scale_units='xy',angles='xy',scale=1,color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show

# %%
vector_1=np.asarray([0,0,4,5])
vector_2=np.asarray([0,0,3,-2])
diff=vector_1-vector_2
print(diff)

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,-8,8,scale_units='xy',angles='xy',scale=1,color='g')
plt.quiver(0,0,1,7,scale_units='xy',angles='xy',scale=1,color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show

# %%
#MULTIPLYING BY SCALER VECTOR
vector_1=np.asarray([0,0,4,5])
vector_2=2*vector_1
print(vector_2)

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,8,10,scale_units='xy',angles='xy',scale=1,color='g')

plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show

# %%
#DOT PRODUCT OF TWO VECTORS
a=np.array([2,3])
b=np.array([4,4])
a_dot_b=np.dot(a,b)
print(a_dot_b)

# %%
c=np.array([40,20,35])
d=np.array([33,43,121])
c_dot_d=np.dot(c,d)
print(c_dot_d)

# %%
#CROSS PRODUCT OF TWO VECTORS
a=np.array([2,3])
b=np.array([4,5])
a_cross_b=np.cross(a,b)
print(a_cross_b)

# %% [markdown]
# #LINEAR REGRESSION

# %%
salary_df=pd.read_csv('/content/Salary_Data.csv')

# %%
import numpy as np

class Linear_Regression:
    def __init__(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, x, y):
        self.m, self.n = x.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.x = x
        self.y = y

        for i in range(self.no_of_iterations):
            self.update_weights()

    def update_weights(self):
        y_prediction = self.predict(self.x)

        dw = -(2 * (self.x.T).dot(self.y - y_prediction)) / self.m
        db = -2 * np.sum(self.y - y_prediction) / self.m

        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, x):
        return x.dot(self.w) + self.b

# %%
#Y=WX+B
#DATA PRE-PROCESSING
salary_df.head()

# %%
salary_df.tail()

# %%
salary_df.shape

# %%
#FINDING MISSING VALUES
salary_df.isnull().sum()

# %%
#SPILITING
x=salary_df.iloc[:,:-1].values
y=salary_df.iloc[:,1].values
print(x)

# %%
print(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=2)

# %%
model=Linear_Regression(learning_rate=0.02,no_of_iterations=1000)

# %%
x = salary_df.iloc[:, [0, 4]].values
y = salary_df.iloc[:, -1].values

# %%
print(x.shape)
print(x[:5])

# %%
print(type(x))

# %%
print(x.dtype)

# %%
salary_df = salary_df.dropna(subset=['Salary'])

x = salary_df.iloc[:, [0, 4]].values
y = salary_df.iloc[:, -1].values

# %%
print(np.isnan(x).sum())
print(np.isnan(y).sum())

# %%
print(y.min())
print(y.max())

# %%
model = Linear_Regression(
    learning_rate=0.000001,
    no_of_iterations=1000
)

model.fit(x, y)

print('weight =', model.w[0])
print('bias =', model.b)

# %%
test_data_prediction=model.predict(x_test)
print(test_data_prediction)

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,test_data_prediction,color='blue')
plt.xlabel('Work Experience')
plt.ylabel('Salary')
plt.title('Salary Vs Experience')

plt.show()

# %% [markdown]
# #IMAGE PROCESSING (DEEP LEARNING)

# %%
#Getting image using web get
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQz0VtnHKvU1kcYSFvU5qGRRjYlISJcoBRyUB27yM_MbA&s=10'

# %% [markdown]
# #LIBRARIES FOR IMAGE PROCESSING
# ...

# %%
import matplotlib.image as mpimg
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
img=mpimg.imread('/content/bangladesh-flag.jpg')

# %%
type(img)

# %%
img.shape

# %%
print(img)

# %%
#DISPLAY IMAGE FROM NUMPY ARRAY TO
plt.imshow(img)

# %%
#RESIZING TE IMAGE USING PILLOW
img=Image.open('/content/bangladesh-flag.jpg')
img_resize=img.resize((200,200))
print(img_resize)

# %%
img_resize.save('/content/bangladesh-flag.jpg')

# %%
img_res=mpimg.imread('/content/bangladesh-flag.jpg')
img_res_plot=plt.imshow(img_res)
plt.show

# %%
img_res.shape

# %%
#CONVERT RGB IMAGE TO GRAY SCALE USING OPENCV
img_gray=cv2.imread('/content/bangladesh-flag.jpg')
img_gray=cv2.cvtColor(img_gray,cv2.COLOR_RGB2GRAY)
type(img_gray)

# %%
img_gray.shape

# %%
cv2_imshow(img_gray)

# %%
#saving the grayscale image
cv2.imwrite('/content/bangladesh-flag.jpg',img_gray)

# %% [markdown]
# #DEEP LEARNING PROJECT

# %% [markdown]
# #import matplotlib.pyplot as plt
# #import matplotlib.image as mpimg
# #from PIL import Image
# #from PIL import ImageOps
# #from PIL import Image
# #import tensorflow as tf
# #tf.random.set_seed(3)
# #from tensorflow import keras
# #from keras.datasets import mnist
# #from tensorflow.math import confusion_matrix
# #import cv2
# #from google.colab.patches import cv2_imshow

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
type(x_train)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)

# %%
print(x_train[10])

# %%
print(x_train[10].shape)

# %%
#DISPLAYING THE IMAGE
plt.imshow(x_train[225])
plt.show

print(y_train[225])

# %%
print(y_train.shape,y_test.shape)

# %%
#unique value in y_tarin and y_test
print(np.unique(y_train))
print(np.unique(y_test))

# %%
#SCALING HE VALUES
x_train=x_train/255
x_test=x_test/255
print(x_train[10])

# %% [markdown]
# #BUILDING THE NEURAL NETWORK

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

# %%
model.compile(
    optimizer='Adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(x_train,y_train,epochs=10)

# %%
#ACCURACY ON TEST DATA
loss,accuracy_score=model.evaluate(x_test,y_test)
print(accuracy_score)

# %%
print(x_test.shape)

# %%
#FIRST DATA IN X_TEST
plt.imshow(x_test[0])
plt.show

# %%
print(y_test[0])

# %%
y_pred=model.predict(x_test)
print(y_pred.shape)

# %%
print(y_pred[0])

# %%
#CONVERTING PRDICTION TO CLASS
label_for_first_test_image=np.argmax(y_pred[0])
print(label_for_first_test_image)

# %%
y_pred_labels=[np.argmax(i) for i in y_pred]
print(y_pred_labels)

# %%
#CONFUSSION MATRIX
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred_labels)
print(conf_mat)

# %%
plt.figure(figsize=(15,7))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
input_image_path='/content/digit 3.jpg'
input_image=cv2.imread(input_image_path)

# %%
type(input_image)

# %%
print(input_image)

# %%
print(input_image.shape)

# %%
cv2_imshow(input_image)

# %%
grayscale=cv2.cvtColor(input_image,cv2.COLOR_RGB2GRAY)

# %%
from google.colab.patches import cv2_imshow

input_image_resize = cv2.resize(grayscale, (28, 28))

# %%
input_image_resize.shape

# %%
cv2_imshow(input_image_resize)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

input_image_path='/content/digit 3.jpg'

input_image=cv2.imread(input_image_path,cv2.IMREAD_GRAYSCALE)

cv2_imshow(input_image)

# %%
input_image_resize=cv2.resize(input_image,(28,28))

cv2_imshow(input_image_resize)

# %%
print(input_image_resize.shape)

# %%
input_image_resize=input_image_resize/255.0

# %%
image_reshaped=np.reshape(input_image_resize,(1,28,28))

# %%
print(image_reshaped.shape)

# %%
input_prediction=model.predict(image_reshaped)
print(input_prediction)

# %%
input_pred_label=np.argmax(input_prediction)

print(input_pred_label)

# %%
#PREDICIVE SYSTEM
input_image_path=input('Enter image path:')
input_image=cv2.imread(input_image_path)
cv2_imshow(input_image)
grayscale=cv2.cvtColor(input_image,cv2.COLOR_RGB2GRAY)
input_image_resize=cv2.resize(input_image,(28,28))
input_image_resize=input_image_resize/255.0
image_reshaped=np.reshape(input_image_resize,(1,28,28))
input_prediction=model.predict(image_reshaped)
input_pred_label=np.argmax(input_prediction)
print(input_pred_label)

# %% [markdown]
# #TRANSFER LEARNING
#
#
# > VGG-16,
# ResNet50,
# Inceptionv3,
# MobileNetV2....

# %% [markdown]
# #Used Dog VS Cat dataset from kaggle

# %%
import os

print(os.path.exists('/content/archive.zip'))
print(os.path.getsize('/content/archive.zip'))

# %%
with open('/content/archive.zip', 'rb') as f:
    print(f.read(20))

# %%
import zipfile

print(zipfile.is_zipfile('/content/archive.zip'))

# %%
import os

print(os.listdir('/content'))

# %%
import os
import zipfile

print("Size:", os.path.getsize('/content/archive.zip'))
print("Is ZIP:", zipfile.is_zipfile('/content/archive.zip'))

# %%
# !file /content/archive.zip

# %%
with open('/content/archive.zip', 'rb') as f:
    f.seek(-100, 2)
    print(f.read())

# %%
# !file /content/archive.zip

# %%
from zipfile import ZipFile

dataset = '/content/archive.zip'

with ZipFile(dataset, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

print('The dataset is extracted')

# %%
# !ls

# %%
import os

# %%
path,dirs,files=next(os.walk('/content/dataset'))
file_count=len(files)
print(file_count)

# %%
fileName=os.listdir()

# %%
fileName=os.listdir('/content/dataset')
print(fileName)

# %%
import os

fileName = os.listdir('/content/dataset/test_data')
print(fileName)

# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

cat_path = '/content/dataset/test_data/cats'

fileName = os.listdir(cat_path)[0]

img = mpimg.imread(os.path.join(cat_path,fileName))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print(os.listdir('/content/dataset/test_data/cats')[:5])

# %%
cat_path = '/content/dataset/test_data/cats'
dog_path = '/content/dataset/test_data/dogs'

cat_file = os.listdir(cat_path)[0]
dog_file = os.listdir(dog_path)[0]

cat_img = mpimg.imread(os.path.join(cat_path, cat_file))
dog_img = mpimg.imread(os.path.join(dog_path, dog_file))

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(cat_img)
plt.title('Cat')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(dog_img)
plt.title('Dog')
plt.axis('off')

plt.show()

# %%
import os

fileName = os.listdir('/content/dataset/test_data')

for i in range(len(fileName)):
    print(fileName[0:5])#i

# %%
fileName=os.listdir('/content/dataset/test_data')
dog_count=0
cat_count=0
for img_file in fileName:
  name=img_file[0:3]
  if name=='dog':
    dog_count+=1
  else:
    cat_count+=1

print('Number of dog images=',dog_count)
print('Number of dog images=',dog_count)

# %%
import os

cat_path = '/content/dataset/test_data/cats'
dog_path = '/content/dataset/test_data/dogs'

cat_files = os.listdir(cat_path)
dog_files = os.listdir(dog_path)

cat_count = len(cat_files)
dog_count = len(dog_files)

print('Number of cat images =', cat_count)
print('Number of dog images =', dog_count)
print('Total images =', cat_count + dog_count)

# %%
os.mkdir('/content/image resized')

# %%
original_folder='/content/dataset/test_data'
resized_folder='/content/image_resized'

os.makedirs(resized_folder,exist_ok=True)

for category in ['cats','dogs']:
    input_folder=os.path.join(original_folder,category)
    output_folder=os.path.join(resized_folder,category)

    os.makedirs(output_folder,exist_ok=True)

    for fileName in os.listdir(input_folder):
        img_path=os.path.join(input_folder,fileName)

        try:
            img=Image.open(img_path)
            img=img.resize((224,224))
            img=img.convert('RGB')

            newImagePath=os.path.join(output_folder,fileName)
            img.save(newImagePath)
        except:
            pass

print('All images resized successfully')

# %%
print(os.listdir('/content/image_resized'))

# %%
cat_files = os.listdir('/content/image_resized/cats')
print(len(cat_files))
print(cat_files[:5])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

fileName = os.listdir('/content/image_resized/cats')[0]

img = mpimg.imread(os.path.join('/content/image_resized/cats', fileName))

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Creating labels for all resized images

# %%
import os

resized_folder='/content/image_resized'

images=[]
labels=[]

for label,category in enumerate(['cats','dogs']):
    folder=os.path.join(resized_folder,category)

    for fileName in os.listdir(folder):
        images.append(os.path.join(folder,fileName))
        labels.append(label)

print('Total images:',len(images))
print('Total labels:',len(labels))
print('First 10 images:',images[:10])
print('First 10 labels:',labels[:10])

# %%
label_names={0:'cats',1:'dogs'}

print(label_names[0])
print(label_names[1])

# %%
label_names={0:'Cat',1:'Dog'}

for label,category in enumerate(['cats','dogs']):
    folder='/content/image_resized/'+category

    fileName=os.listdir(folder)[0]

    img=mpimg.imread(os.path.join(folder,fileName))

    plt.imshow(img)
    plt.title('Label: '+label_names[label])
    plt.axis('off')
    plt.show()

# %%
fileName=os.listdir('/content/image_resized/cats')[0]

img=Image.open('/content/image_resized/cats/'+fileName)

print(img.size)

# %%
values,counts=np.unique(labels,return_counts=True)
print(values,counts)

# %%
print('Cats:', len(os.listdir(cat_path)))
print('Dogs:', len(os.listdir(dog_path)))

# %%
#CONVERTING ALL THE RESIZE IMAGE TO NUMPY ARRAY
import cv2
import glob

# %%
import os
import cv2
import numpy as np

x = []
y = []

cat_path = '/content/image_resized/cats'
dog_path = '/content/image_resized/dogs'

for file in os.listdir(cat_path):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        img = cv2.imread(os.path.join(cat_path, file))
        if img is not None:
            x.append(img)
            y.append(0)

for file in os.listdir(dog_path):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        img = cv2.imread(os.path.join(dog_path, file))
        if img is not None:
            x.append(img)
            y.append(1)

x = np.array(x)
y = np.array(y)

print("X shape:", x.shape)
print("Y shape:", y.shape)
print("Number of images:", len(x))
print("Number of labels:", len(y))
print("Number of cats:", np.sum(y == 0))
print("Number of dogs:", np.sum(y == 1))

# %%
original_dog_path = '/content/dataset/test_data/dogs'#missing dog finding

# %%
original_dogs = set(
    f for f in os.listdir(original_dog_path)
    if f.lower().endswith(('.jpg', '.jpeg', '.png'))
)

resized_dogs = set(
    f for f in os.listdir(dog_path)
    if f.lower().endswith(('.jpg', '.jpeg', '.png'))
)

missing_dogs = original_dogs - resized_dogs

print('Original dogs:', len(original_dogs))
print('Resized dogs:', len(resized_dogs))
print('Missing dogs:', len(missing_dogs))

for f in missing_dogs:
    print(f)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=2,
    stratify=y
)

print("X_train:", x_train.shape)
print("X_test:", x_test.shape)
print("Y_train:", y_train.shape)
print("Y_test:", y_test.shape)

# %%
print("X:", len(x))
print("Y:", len(y))

# %%
#SCALING
x_train_scaled=x_train/255.0

x_test_scaled=x_test/255.0

# %%
print(x_train_scaled)

# %%
#BUILDING NEURAL NETWORK
import tensorflow as tf
import tensorflow_hub as hub

# %% [markdown]
# #THIS LINK 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4 ' copied from Tensorflow hub

# %%
# !pip install -q tf-keras tensorflow-hub

# %%
mobilenet_model='https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'
pretrained_model=hub.KerasLayer(
    mobilenet_model,
    input_shape=(224, 224, 3),
    trainable=False
)

# %%
num_of_classes=2
model=tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Dense(num_of_classes)

])
model.summary()

# %%
model.compile(
    optimizer='adams',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    matrics=['abc']
)

# %%
model.fit(x_train_scaled,y_train,epochs=5)

# %%
score,acc=model.evaluate(x_test_scaled,y_test)
print('Test Loss=',score)
print('Test Accuracy=',acc)

# %%
#PREDICTIVE SYSTEM
input_image_path=input('path of the image to be predicted=')
input_image=cv2.imread(input_image_path)
cv2.imshow(input_image)
input_image_resize=cv2.resize(input_image,(22,224))
input_image_scaled=input_image_resize/255.0
input_image_reshaped=np.reshape(input_image_scaled,(1,224,224,3))
input_prediction=model.predict(input_image_reshaped)
input_pred_label=np.argmax(input_prediction)
print(input_pred_label)
if input_pred_label==0:
  print('The image represent a cat')
else:
  print('The image represent a dog')#download a dog and a cat image and then give their file explorer path as input

# %% [markdown]
# #MUSIC RECOMMENDATION SYSTEM
#
# > import os
# import json
# import zipfile
# from sklearn.feature_exraction.text import TfidVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.metrics.pairwise import
# import re
# import nltk
# from wordcloud import WordCloud
# from nltk.corpus import stopwords
# from nltl.tokenize import word_tokenize

# %% [markdown]
# spotify million song dataset from kaggle used here

# %%
# !pip install kaggle -q

# %%
import zipfile

with zipfile.ZipFile('/content/spotify_millsongdata.csv.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
print(os.listdir('/content/'))

# %%
import pandas as pd

df = pd.read_csv('/content/spotify_millsongdata.csv')

print(df.shape)

# %%
print(df.head())

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
top_artist=df['artist'].value_counts().head(10)
print(top_artist)

# %%
df=df.sample(10000)
df=df.drop('link',axis=1).reset_index(drop=True)

# %%
df.head()

# %%
all_lyrics = ' '.join(df['text'].dropna())

wordcloud = WordCloud(
    width=1000,
    height=440,
    background_color='white'
).generate(all_lyrics)

# %%
plt.figure(figsize=(15,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#DOWNLOAD NLTK DATA
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
stop_words=set(stopwords.words('english'))

# %% [markdown]
# DATA CLEANING PROCESS

# %%
def preprocess_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# %%
df['cleaned_text'] = df['text'].apply(preprocess_text)

# %%
df.head()

# %%
#VECTORIZAION WITH TF-IDF
tfidf_vectorizer=TfidfVectorizer ( max_features=5000)
tfidf_matrix=tfidf_vectorizer.fit_transform(df['cleaned_text'])

# %%
df['cleaned_text']

# %%
cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
def recommended_songs(song_name, cosine_sim=cosine_sim, df=df, top_n=5):
    song_index = df[df['song'].str.lower() == song_name.lower()].index
    if len(song_index) == 0:
        return 'Song not found in the dataset'

    song_index = song_index[0]
    sim_score = list(enumerate(cosine_sim[song_index]))
    sim_score = sorted(sim_score, key=lambda x: x[1], reverse=True)
    sim_score = sim_score[1:top_n+1]
    song_indices = [i[0] for i in sim_score]

    return df[['artist', 'song']].iloc[song_indices]

# %%
df['song'][2]

# %%
#RECOMMMENDATION
print('Recommended Songs')
recommendations=recommended_songs('Christmass Memories')
print(recommendations)

# %%
recommendations=recommended_songs('For The First Time')
print(recommendations)

# %%
def recommend_songs(song_name, cosine_sim=cosine_sim, df=df, top_n=5):
    idx = df[df['song'].str.lower() == song_name.lower()].index

    if len(idx) == 0:
        return "Song not found in the dataset!"

    idx = idx[0]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]

    song_indices = [i[0] for i in sim_scores]

    recommendations = df[['artist', 'song']].iloc[song_indices].copy()
    recommendations['similarity'] = [round(score, 3) for _, score in sim_scores]

    return recommendations

# %%
recommend_songs("For The First Time")

# %%
song_name = input("Enter a song name: ")

recommendations = recommend_songs(song_name)

print("\nRecommended Songs:")
print(recommendations)
